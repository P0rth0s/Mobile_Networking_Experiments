# %%
import csv
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import time
import folium

# %%
def getLocationInformation():
    with open('prefix_lat_lon_name_category.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        locations = []
        for row in csv_input:
            locations.append(row)
        return locations

# %%
def eventTimeblocks(data):
    sixThirty = 390
    nineThirty = 570
    elevenThirty = 720
    fourteenThirty = 870
    seventeenThirty = 1050
    twentyThirty = 1230
    earlyBirds = []
    munchers = []
    stompers = []
    for row in data:
        if row['startTime'] > sixThirty and row['startTime'] < nineThirty:
            earlyBirds.append(row)
        elif row['startTime'] > elevenThirty and row['startTime'] < fourteenThirty:
            munchers.append(row)
        elif row['startTime'] > seventeenThirty and row['startTime'] < twentyThirty:
            stompers.append(row)
    return (earlyBirds, munchers, stompers)

# %%
def userDensityMap(data, locationData):
    m = folium.Map(
        location=[29.6436, 82.3549],
        zoom_start=12,
        tiles='Stamen Toner'
    )
    tooltip = 'Click Me For Data'
    for loc in locationData:
        loc['density'] = 0
        for event in data:
            if event['APNAME'] == loc['prefix']:
                loc['density'] += 1
        folium.Marker([loc['lat'], loc['lon']], popup=loc['name'] + ': ' + str(loc['density']), tooltip=tooltip).add_to(m)
    m

# %%
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        userDensityMap(timeblockData[TIMEBLOCK], locationData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f5af0b82f9b6> in <module>
#       8         t1 = time.gmtime(int(row['startTime']))
#       9         t2 = time.gmtime(int(row['endTime']))
# ---> 10         row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
#      11         row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
#      12         row['APNAME'] = get_location_prefix(row)
#
# NameError: name 'getHourEDT' is not defined

# %%
def getHourEDT(hourGMT):
    hourEDT = hourGMT - 4
    if(hourEDT < 0):
        hourEDT = 24 + hourEDT
    return hourEDT

# %%
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        userDensityMap(timeblockData[TIMEBLOCK], locationData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f5af0b82f9b6> in <module>
#      10         row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
#      11         row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
# ---> 12         row['APNAME'] = get_location_prefix(row)
#      13         userMacList.append(row['userMAC'])
#      14     sortedData = sorted(data, key=lambda row: row['startTime'])
#
# NameError: name 'get_location_prefix' is not defined

# %%
def get_location_prefix(row):
    stri = ''
    for char in row['APNAME']:
        if(char.isdigit()):
            break
        else:
            stri += char
    return stri

# %%
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        userDensityMap(timeblockData[TIMEBLOCK], locationData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f5af0b82f9b6> in <module>
#      15     locationData = getLocationInformation()
#      16     timeblockData = eventTimeblocks(sortedData)
# ---> 17     userDensityMap(timeblockData[TIMEBLOCK], locationData)
#
# NameError: name 'TIMEBLOCK' is not defined

# %%
    TIMEBLOCK = 0
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        userDensityMap(timeblockData[TIMEBLOCK], locationData)

# %%
def userDensityMap(data, locationData):
    m = folium.Map(
        location=[29.6436, 82.3549],
        zoom_start=12,
        tiles='Stamen Toner'
    )
    tooltip = 'Click Me For Data'
    for loc in locationData:
        loc['density'] = 0
        for event in data:
            if event['APNAME'] == loc['prefix']:
                loc['density'] += 1
        folium.Marker([loc['lat'], loc['lon']], popup=loc['name'] + ': ' + str(loc['density']), tooltip=tooltip).add_to(m)
    return m

# %%
    TIMEBLOCK = 0
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        m = userDensityMap(timeblockData[TIMEBLOCK], locationData)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def userDensityMap(data, locationData):
    m = folium.Map(
        location=[29.6436, 82.3549],
        zoom_start=12,
        tiles='Stamen Toner'
    )
    tooltip = 'Click Me For Data'
    for loc in locationData:
        loc['density'] = 0
        for event in data:
            if event['APNAME'] == loc['prefix']:
                loc['density'] += 1
        folium.Marker([loc['lat'], loc['lon']], icon=loc['name'] + ': ' + str(loc['density'])).add_to(m)
    return m

# %%
    TIMEBLOCK = 0
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        m = userDensityMap(timeblockData[TIMEBLOCK], locationData)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-6c10033ac888> in <module>
#      16     locationData = getLocationInformation()
#      17     timeblockData = eventTimeblocks(sortedData)
# ---> 18     m = userDensityMap(timeblockData[TIMEBLOCK], locationData)
#
# <ipython-input-14-3ded5d65b3b7> in userDensityMap(data, locationData)
#      11             if event['APNAME'] == loc['prefix']:
#      12                 loc['density'] += 1
# ---> 13         folium.Marker([loc['lat'], loc['lon']], icon=loc['name'] + ': ' + str(loc['density'])).add_to(m)
#      14     return m
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/folium/map.py in __init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     282         )
#     283         if icon is not None:
# --> 284             self.add_child(icon)
#     285         if popup is not None:
#     286             self.add_child(popup if isinstance(popup, Popup)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/branca/element.py in add_child(self, child, name, index)
#     103         """Add a child."""
#     104         if name is None:
# --> 105             name = child.get_name()
#     106         if index is None:
#     107             self._children[name] = child
#
# AttributeError: 'str' object has no attribute 'get_name'

# %%
def userDensityMap(data, locationData):
    m = folium.Map(
        location=[29.6436, 82.3549],
        zoom_start=12,
        tiles='Stamen Toner'
    )
    tooltip = 'Click Me For Data'
    for loc in locationData:
        loc['density'] = 0
        for event in data:
            if event['APNAME'] == loc['prefix']:
                loc['density'] += 1
        folium.Marker([loc['lat'], loc['lon']], icon=folium.DivIcon(html=f"""<div><p>{loc['name']}: {str(loc['density'])}</div>""").add_to(m)
    return m
# Out:
#   File "<ipython-input-16-9b87063492b0>", line 14
#     return m
#     ^
# SyntaxError: invalid syntax

# %%
def userDensityMap(data, locationData):
    m = folium.Map(
        location=[29.6436, 82.3549],
        zoom_start=12,
        tiles='Stamen Toner'
    )
    tooltip = 'Click Me For Data'
    for loc in locationData:
        loc['density'] = 0
        for event in data:
            if event['APNAME'] == loc['prefix']:
                loc['density'] += 1
        folium.Marker([loc['lat'], loc['lon']], icon=folium.DivIcon(html=f"""<div><p>{loc['name']}: {str(loc['density'])}</div>""")).add_to(m)
    return m

# %%
    TIMEBLOCK = 0
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        m = userDensityMap(timeblockData[TIMEBLOCK], locationData)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def userDensityMap(data, locationData):
    m = folium.Map(
        location=[29.6436, 82.3549],
        zoom_start=12,
        tiles='Stamen Toner'
    )
    tooltip = 'Click Me For Data'
    for loc in locationData:
        loc['density'] = 0
        for event in data:
            if event['APNAME'] == loc['prefix']:
                loc['density'] += 1
        folium.Marker([loc['lat'], loc['lon']], icon=folium.DivIcon(html=f"""<div><p>{str(loc['density'])}</div>""")).add_to(m)
    return m

# %%
    TIMEBLOCK = 0
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        m = userDensityMap(timeblockData[TIMEBLOCK], locationData)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
    TIMEBLOCK = 1
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        m = userDensityMap(timeblockData[TIMEBLOCK], locationData)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
    TIMEBLOCK = 2
    with open('outputwireless-logs-20120407.DHCP_ANON.csv', mode='r') as csv_file:
        csv_input = csv.DictReader(csv_file)
        userMacList = []
        data = []
        for row in csv_input:
            data.append(row)
        for row in data:
            t1 = time.gmtime(int(row['startTime']))
            t2 = time.gmtime(int(row['endTime']))
            row['startTime'] = (getHourEDT(t1[3]) * 60) + t1[4]
            row['endTime'] = (getHourEDT(t2[3]) * 60) + t2[4]
            row['APNAME'] = get_location_prefix(row)
            userMacList.append(row['userMAC'])
        sortedData = sorted(data, key=lambda row: row['startTime'])
        locationData = getLocationInformation()
        timeblockData = eventTimeblocks(sortedData)
        m = userDensityMap(timeblockData[TIMEBLOCK], locationData)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
